# %% [markdown]
# <a href="https://colab.research.google.com/github/WeizmannML/course2020/blob/master/Tutorial6/Graph_Classification_DGL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dgl
# !pip install networkx
import torch as th
from torch import nn
import torch.nn.functional as F
from torch.nn import init
import dgl.function as fn 
from dgl.base import DGLError
# Out:
# Using backend: pytorch

# %%
import torch
import dgl

# %% [markdown]
# ## The graph classifier will be built out of two graph-convolution layers

# %% [markdown]
# ## The graph convolution  : <br>   $h_i^{(l+1)} = \sigma(b^{(l)} + \sum_{j\in\mathcal{N}(i)}\frac{1}{c_{ij}}h_j^{(l)}W^{(l)})$ <br> with $c_{ij} = \sqrt{|\mathcal{N}(i)|}\sqrt{|\mathcal{N}(j)|}$ ; <br> $H^{(l+1)} = \sigma ( \tilde{D}^{-\frac{1}{2}} \tilde{A} \tilde{D}^{-\frac{1}{2}} W^{l}h^{l} ) $

# %%
# implemented in https://docs.dgl.ai/_modules/dgl/nn/pytorch/conv/graphconv.html#GraphConv
class GraphConv(nn.Module):
    r"""Apply graph convolution over an input signal.

    Graph convolution is introduced in `GCN <https://arxiv.org/abs/1609.02907>`__
    and can be described as below:

    .. math::
      h_i^{(l+1)} = \sigma(b^{(l)} + \sum_{j\in\mathcal{N}(i)}\frac{1}{c_{ij}}h_j^{(l)}W^{(l)})

    where :math:`\mathcal{N}(i)` is the neighbor set of node :math:`i`. :math:`c_{ij}` is equal
    to the product of the square root of node degrees:
    :math:`\sqrt{|\mathcal{N}(i)|}\sqrt{|\mathcal{N}(j)|}`. :math:`\sigma` is an activation
    function.

    The model parameters are initialized as in the
    `original implementation <https://github.com/tkipf/gcn/blob/master/gcn/layers.py>`__ where
    the weight :math:`W^{(l)}` is initialized using Glorot uniform initialization
    and the bias is initialized to be zero.

    Notes
    -----
    Zero in degree nodes could lead to invalid normalizer. A common practice
    to avoid this is to add a self-loop for each node in the graph, which
    can be achieved by:

    >>> g = ... # some DGLGraph
    >>> g.add_edges(g.nodes(), g.nodes())


    Parameters
    ----------
    in_feats : int
        Input feature size.
    out_feats : int
        Output feature size.
    norm : str, optional
        How to apply the normalizer. If is `'right'`, divide the aggregated messages
        by each node's in-degrees, which is equivalent to averaging the received messages.
        If is `'none'`, no normalization is applied. Default is `'both'`,
        where the :math:`c_{ij}` in the paper is applied.
    weight : bool, optional
        If True, apply a linear layer. Otherwise, aggregating the messages
        without a weight matrix.
    bias : bool, optional
        If True, adds a learnable bias to the output. Default: ``True``.
    activation: callable activation function/layer or None, optional
        If not None, applies an activation function to the updated node features.
        Default: ``None``.

    Attributes
    ----------
    weight : torch.Tensor
        The learnable weight tensor.
    bias : torch.Tensor
        The learnable bias tensor.
    """
    def __init__(self,
                 in_feats,
                 out_feats,
                 norm='both',
                 weight=True,
                 bias=True,
                 activation=None):
        super(GraphConv, self).__init__()
        if norm not in ('none', 'both', 'right'):
            raise DGLError('Invalid norm value. Must be either "none", "both" or "right".'
                           ' But got "{}".'.format(norm))
        self._in_feats = in_feats
        self._out_feats = out_feats
        self._norm = norm

        if weight:
            self.weight = nn.Parameter(th.Tensor(in_feats, out_feats))
        else:
            self.register_parameter('weight', None)

        if bias:
            self.bias = nn.Parameter(th.Tensor(out_feats))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

        self._activation = activation

    def reset_parameters(self):
        """Reinitialize learnable parameters."""
        if self.weight is not None:
            init.xavier_uniform_(self.weight)
        if self.bias is not None:
            init.zeros_(self.bias)


    def forward(self, graph, feat, weight=None):
        """Compute graph convolution.

        Notes
        -----
        * Input shape: :math:`(N, *, \text{in_feats})` where * means any number of additional
          dimensions, :math:`N` is the number of nodes.
        * Output shape: :math:`(N, *, \text{out_feats})` where all but the last dimension are
          the same shape as the input.
        * Weight shape: "math:`(\text{in_feats}, \text{out_feats})`.

        Parameters
        ----------
        graph : DGLGraph
            The graph.
        feat : torch.Tensor
            The input feature
        weight : torch.Tensor, optional
            Optional external weight tensor.

        Returns
        -------
        torch.Tensor
            The output feature
        """
        graph = graph.local_var()

        if self._norm == 'both':
            degs = graph.out_degrees().to(feat.device).float().clamp(min=1)
            norm = th.pow(degs, -0.5)
            shp = norm.shape + (1,) * (feat.dim() - 1)
            norm = th.reshape(norm, shp)
            feat = feat * norm

        if weight is not None:
            if self.weight is not None:
                raise DGLError('External weight is provided while at the same time the'
                               ' module has defined its own weight parameter. Please'
                               ' create the module with flag weight=False.')
        else:
            weight = self.weight

        if self._in_feats > self._out_feats:
            # mult W first to reduce the feature size for aggregation.
            if weight is not None:
                feat = th.matmul(feat, weight)
            graph.srcdata['h'] = feat
            graph.update_all(fn.copy_src(src='h', out='m'),
                             fn.sum(msg='m', out='h'))
            rst = graph.dstdata['h']
        else:
            # aggregate first then mult W
            graph.srcdata['h'] = feat
            graph.update_all(fn.copy_src(src='h', out='m'),
                             fn.sum(msg='m', out='h'))
            rst = graph.dstdata['h']
            if weight is not None:
                rst = th.matmul(rst, weight)

        if self._norm != 'none':
            degs = graph.in_degrees().to(feat.device).float().clamp(min=1)
            if self._norm == 'both':
                norm = th.pow(degs, -0.5)
            else:
                norm = 1.0 / degs
            shp = norm.shape + (1,) * (feat.dim() - 1)
            norm = th.reshape(norm, shp)
            rst = rst * norm

        if self.bias is not None:
            rst = rst + self.bias

        if self._activation is not None:
            rst = self._activation(rst)

        return rst


    def extra_repr(self):
        """Set the extra representation of the module,
        which will come into effect when printing the model.
        """
        summary = 'in={_in_feats}, out={_out_feats}'
        summary += ', normalization={_norm}'
        if '_activation' in self.__dict__:
            summary += ', activation={_activation}'
        return summary.format(**self.__dict__)

# %%
from dgl.data import MiniGCDataset
import matplotlib.pyplot as plt
import networkx as nx
# A dataset with 80 samples, each graph is
# of size [10, 20]
dataset = MiniGCDataset(80, 10, 20)
graph, label = dataset[0]
fig, ax = plt.subplots()
nx.draw(graph.to_networkx(), ax=ax)
ax.set_title('Class: {:d}'.format(label))
plt.show()

# %%
dataset.graphs
# Out:
# [Graph(num_nodes=15, num_edges=45,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=30,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=39,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=39,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=51,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=19, num_edges=57,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=39,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=45,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=36,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=42,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=49,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=46,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=52,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=52,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=11, num_edges=31,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=46,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=49,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=49,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=52,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=11, num_edges=31,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=71,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=19, num_edges=91,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=86,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=19, num_edges=91,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=66,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=61,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=46,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=61,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=71,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=46,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=64,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=234,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=109,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=79,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=231,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=11, num_edges=73,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=19, num_edges=295,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=96,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=64,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=106,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=80,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=80,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=32,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=80,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=72,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=9, num_edges=33,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=59,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=59,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=36,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=8, num_edges=28,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=46,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=64,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=36,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=44,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=196,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=169,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=196,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=196,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=324,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=196,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=13, num_edges=169,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=17, num_edges=289,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=225,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=15, num_edges=225,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=40,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=40,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=56,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=18, num_edges=72,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=48,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=40,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=14, num_edges=56,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=40,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=10, num_edges=40,
#        ndata_schemes={}
#        edata_schemes={}),
#  Graph(num_nodes=12, num_edges=48,
#        ndata_schemes={}
#        edata_schemes={})]

# %%
dataset.max_num_v, dataset.num_classes
# Out:
# (20, 8)

# %%
class_names ={   
   0 : 'cycle graph',
   1 : 'star graph',
   2 : 'wheel graph',
   3 : 'lollipop graph',
   4 : 'hypercube graph',
   5 : 'grid graph',
   6 : 'clique graph',
   7 : 'circular ladder graph',
}

# %%
plt.rcParams["figure.figsize"]=18,12
fig, axes = plt.subplots(nrows=2, ncols=4)

iter = 0
for ax in axes.flatten() : 
    
    graph, label = dataset[10 * iter]
    
    nx.draw(graph.to_networkx(), with_labels=True, ax=ax)
    
    ax.set_title('Class: {:d}'.format(label.item() ) +', '+class_names[label.item()] )
    
    iter += 1
  

plt.show()

# %% [markdown]
# # Forming a graph minibatch
#
# ## In general different elements of a batch can have different shapes (slide)

# %%
def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    return batched_graph, torch.tensor(labels)

# %% [markdown]
# # Readout & Classification
# ###For this demonstration, consider initial node features to be their degrees. After two rounds of graph convolution, perform a graph readout by averaging over all node features for each graph in the batch. <br> $h_g = \frac{1}{\mathcal{|N|}} \sum_{\nu \in \mathcal{N}} h_{\nu} $

# %%
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = GraphConv(in_dim, hidden_dim)
        self.conv2 = GraphConv(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g):
        # Use node degree as the initial node feature. For undirected graphs, the in-degree
        # is the same as the out_degree.
        h = g.in_degrees().view(-1, 1).float()
        # Perform graph convolution and activation function.
        h = F.relu(self.conv1(g, h))
        h = F.relu(self.conv2(g, h))
        g.ndata['h'] = h
        # Calculate graph representation by averaging all the node representations.
        hg = dgl.mean_nodes(g, 'h')
        return self.classify(hg)

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

# Create training and test sets.
trainset = MiniGCDataset(1000, 10, 20)
testset = MiniGCDataset(300, 10, 20)
validset = MiniGCDataset(200, 10, 20)
# Use PyTorch's DataLoader and the collate function
# defined before.
data_loader = DataLoader(trainset, batch_size=32, shuffle=True,
                         collate_fn=collate)

val_data_loader = DataLoader(validset, batch_size=42, shuffle=True,
                         collate_fn=collate)

test_data_loader = DataLoader(testset, batch_size=42, shuffle=True,
                         collate_fn=collate)

# Create model
model = Classifier(1, 256, trainset.num_classes)
#model = model.cuda()

# if torch.cuda.is_available():
#     model = model.cuda()


loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model
# Out:
# Classifier(
#   (conv1): GraphConv(in=1, out=256, normalization=both, activation=None)
#   (conv2): GraphConv(in=256, out=256, normalization=both, activation=None)
#   (classify): Linear(in_features=256, out_features=8, bias=True)
# )

# %%
## --------- Run the training loop ------------------- ##

n_epoch = 200

epoch_losses, epoch_val_losses = [], []
for epoch in range(1, n_epoch+1):
    epoch_loss = 0
    iter_batch = 0
    model.train()
    for bg, label in data_loader:

        # if torch.cuda.is_available():
        #    bg = bg.cuda()
        #    label = label.cuda()

        prediction = model(bg)
        
        loss = loss_func(prediction, label )
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
        iter_batch += 1
    epoch_loss /= (iter_batch + 1)
    #print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_losses.append(epoch_loss)
    
    
    epoch_val_loss = 0
    iter_batch_val = 0
    model.eval()
    for bg, label in val_data_loader:
            
        prediction = model(bg)
        loss = loss_func(prediction, label )
        epoch_val_loss += loss.detach().item()
        iter_batch_val += 1
    epoch_val_loss /= (iter_batch_val + 1)
    #print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_val_losses.append(epoch_val_loss)
    
    print('Epoch {}, loss {:.4f}, val_loss {:.4f}'.format(epoch, epoch_loss, epoch_val_loss))
# Out:
# Epoch 1, loss 1.9226, val_loss 1.6229
# Epoch 2, loss 1.8872, val_loss 1.5885
# Epoch 3, loss 1.8321, val_loss 1.5419
# Epoch 4, loss 1.7516, val_loss 1.4316
# Epoch 5, loss 1.5912, val_loss 1.2981
# Epoch 6, loss 1.4358, val_loss 1.1425
# Epoch 7, loss 1.2621, val_loss 1.0016
# Epoch 8, loss 1.1414, val_loss 0.9017
# Epoch 9, loss 1.0479, val_loss 0.8396
# Epoch 10, loss 0.9651, val_loss 0.8042
# Epoch 11, loss 0.9044, val_loss 0.7437
# Epoch 12, loss 0.8500, val_loss 0.7407
# Epoch 13, loss 0.8298, val_loss 0.6981
# Epoch 14, loss 0.7999, val_loss 0.6862
# Epoch 15, loss 0.8164, val_loss 0.6993
# Epoch 16, loss 0.7599, val_loss 0.6426
# Epoch 17, loss 0.7432, val_loss 0.6505
# Epoch 18, loss 0.7496, val_loss 0.6254
# Epoch 19, loss 0.7227, val_loss 0.6067
# Epoch 20, loss 0.6948, val_loss 0.5973
# Epoch 21, loss 0.7037, val_loss 0.5907
# Epoch 22, loss 0.6763, val_loss 0.5902
# Epoch 23, loss 0.6812, val_loss 0.5778
# Epoch 24, loss 0.6750, val_loss 0.5605
# Epoch 25, loss 0.6667, val_loss 0.5626
# Epoch 26, loss 0.6367, val_loss 0.5450
# Epoch 27, loss 0.6361, val_loss 0.5332
# Epoch 28, loss 0.6481, val_loss 0.5526
# Epoch 29, loss 0.6451, val_loss 0.5357
# Epoch 30, loss 0.6140, val_loss 0.5525
# Epoch 31, loss 0.6224, val_loss 0.5161
# Epoch 32, loss 0.6004, val_loss 0.5047
# Epoch 33, loss 0.5858, val_loss 0.5208
# Epoch 34, loss 0.5939, val_loss 0.5087
# Epoch 35, loss 0.5668, val_loss 0.4994
# Epoch 36, loss 0.5841, val_loss 0.5038
# Epoch 37, loss 0.5565, val_loss 0.5060
# Epoch 38, loss 0.5877, val_loss 0.4922
# Epoch 39, loss 0.5599, val_loss 0.4828
# Epoch 40, loss 0.5929, val_loss 0.4921
# Epoch 41, loss 0.5333, val_loss 0.4568
# Epoch 42, loss 0.5385, val_loss 0.4740
# Epoch 43, loss 0.5203, val_loss 0.4810
# Epoch 44, loss 0.5437, val_loss 0.4750
# Epoch 45, loss 0.5421, val_loss 0.4564
# Epoch 46, loss 0.5199, val_loss 0.4748
# Epoch 47, loss 0.5003, val_loss 0.4588
# Epoch 48, loss 0.5247, val_loss 0.4386
# Epoch 49, loss 0.4972, val_loss 0.4518
# Epoch 50, loss 0.4911, val_loss 0.4393
# Epoch 51, loss 0.4924, val_loss 0.4442
# Epoch 52, loss 0.4945, val_loss 0.4062
# Epoch 53, loss 0.4675, val_loss 0.4047
# Epoch 54, loss 0.4530, val_loss 0.3976
# Epoch 55, loss 0.4401, val_loss 0.3858
# Epoch 56, loss 0.4657, val_loss 0.4010
# Epoch 57, loss 0.4375, val_loss 0.3779
# Epoch 58, loss 0.4288, val_loss 0.3896
# Epoch 59, loss 0.4319, val_loss 0.3756
# Epoch 60, loss 0.4347, val_loss 0.3702
# Epoch 61, loss 0.4230, val_loss 0.3475
# Epoch 62, loss 0.4148, val_loss 0.3550
# Epoch 63, loss 0.4041, val_loss 0.3447
# Epoch 64, loss 0.4157, val_loss 0.3405
# Epoch 65, loss 0.3963, val_loss 0.3334
# Epoch 66, loss 0.3782, val_loss 0.3251
# Epoch 67, loss 0.3856, val_loss 0.3287
# Epoch 68, loss 0.3838, val_loss 0.3522
# Epoch 69, loss 0.3876, val_loss 0.3241
# Epoch 70, loss 0.3861, val_loss 0.3353
# Epoch 71, loss 0.3672, val_loss 0.3080
# Epoch 72, loss 0.3636, val_loss 0.3024
# Epoch 73, loss 0.3776, val_loss 0.3130
# Epoch 74, loss 0.3606, val_loss 0.3134
# Epoch 75, loss 0.3363, val_loss 0.2885
# Epoch 76, loss 0.3521, val_loss 0.2969
# Epoch 77, loss 0.3612, val_loss 0.2993
# Epoch 78, loss 0.3308, val_loss 0.2842
# Epoch 79, loss 0.3292, val_loss 0.3166
# Epoch 80, loss 0.3242, val_loss 0.3016
# Epoch 81, loss 0.3282, val_loss 0.2693
# Epoch 82, loss 0.3153, val_loss 0.3039
# Epoch 83, loss 0.3417, val_loss 0.2819
# Epoch 84, loss 0.3105, val_loss 0.2696
# Epoch 85, loss 0.3133, val_loss 0.2786
# Epoch 86, loss 0.3152, val_loss 0.2710
# Epoch 87, loss 0.3411, val_loss 0.2655
# Epoch 88, loss 0.3020, val_loss 0.2650
# Epoch 89, loss 0.2972, val_loss 0.2467
# Epoch 90, loss 0.3050, val_loss 0.2762
# Epoch 91, loss 0.2967, val_loss 0.2552
# Epoch 92, loss 0.3007, val_loss 0.2504
# Epoch 93, loss 0.3367, val_loss 0.2438
# Epoch 94, loss 0.3049, val_loss 0.2478
# Epoch 95, loss 0.3068, val_loss 0.2501
# Epoch 96, loss 0.3023, val_loss 0.2706
# Epoch 97, loss 0.2823, val_loss 0.2504
# Epoch 98, loss 0.2789, val_loss 0.2330
# Epoch 99, loss 0.2838, val_loss 0.2403
# Epoch 100, loss 0.2866, val_loss 0.2444
# Epoch 101, loss 0.2749, val_loss 0.2357
# Epoch 102, loss 0.2771, val_loss 0.2576
# Epoch 103, loss 0.2806, val_loss 0.2360
# Epoch 104, loss 0.2679, val_loss 0.2416
# Epoch 105, loss 0.2743, val_loss 0.2345
# Epoch 106, loss 0.2662, val_loss 0.2394
# Epoch 107, loss 0.2713, val_loss 0.2267
# Epoch 108, loss 0.2706, val_loss 0.2234
# Epoch 109, loss 0.2681, val_loss 0.2342
# Epoch 110, loss 0.2671, val_loss 0.2315
# Epoch 111, loss 0.2620, val_loss 0.2171
# Epoch 112, loss 0.2738, val_loss 0.2424
# Epoch 113, loss 0.2607, val_loss 0.2070
# Epoch 114, loss 0.2569, val_loss 0.2149
# Epoch 115, loss 0.2570, val_loss 0.2190
# Epoch 116, loss 0.2511, val_loss 0.2073
# Epoch 117, loss 0.2601, val_loss 0.2190
# Epoch 118, loss 0.2610, val_loss 0.2272
# Epoch 119, loss 0.2604, val_loss 0.2288
# Epoch 120, loss 0.2468, val_loss 0.2031
# Epoch 121, loss 0.2510, val_loss 0.2049
# Epoch 122, loss 0.2440, val_loss 0.2078
# Epoch 123, loss 0.2430, val_loss 0.2092
# Epoch 124, loss 0.2500, val_loss 0.2199
# Epoch 125, loss 0.2541, val_loss 0.2152
# Epoch 126, loss 0.2549, val_loss 0.2148
# Epoch 127, loss 0.2459, val_loss 0.2050
# Epoch 128, loss 0.2517, val_loss 0.2027
# Epoch 129, loss 0.2441, val_loss 0.2169
# Epoch 130, loss 0.2337, val_loss 0.1947
# Epoch 131, loss 0.2421, val_loss 0.2184
# Epoch 132, loss 0.2524, val_loss 0.2010
# Epoch 133, loss 0.2478, val_loss 0.2052
# Epoch 134, loss 0.2491, val_loss 0.1994
# Epoch 135, loss 0.2357, val_loss 0.2262
# Epoch 136, loss 0.2406, val_loss 0.2156
# Epoch 137, loss 0.2408, val_loss 0.2080
# Epoch 138, loss 0.2380, val_loss 0.2076
# Epoch 139, loss 0.2676, val_loss 0.2029
# Epoch 140, loss 0.2623, val_loss 0.2315
# Epoch 141, loss 0.2591, val_loss 0.2419
# Epoch 142, loss 0.2604, val_loss 0.2028
# Epoch 143, loss 0.2387, val_loss 0.1938
# Epoch 144, loss 0.2445, val_loss 0.1921
# Epoch 145, loss 0.2297, val_loss 0.1867
# Epoch 146, loss 0.2359, val_loss 0.1849
# Epoch 147, loss 0.2186, val_loss 0.1883
# Epoch 148, loss 0.2154, val_loss 0.1823
# Epoch 149, loss 0.2242, val_loss 0.1880
# Epoch 150, loss 0.2305, val_loss 0.1994
# Epoch 151, loss 0.2324, val_loss 0.1839
# Epoch 152, loss 0.2287, val_loss 0.1825
# Epoch 153, loss 0.2209, val_loss 0.1920
# Epoch 154, loss 0.2419, val_loss 0.1995
# Epoch 155, loss 0.2297, val_loss 0.1842
# Epoch 156, loss 0.2234, val_loss 0.3441
# Epoch 157, loss 0.2666, val_loss 0.1854
# Epoch 158, loss 0.2331, val_loss 0.1852
# Epoch 159, loss 0.2177, val_loss 0.1863
# Epoch 160, loss 0.2275, val_loss 0.1852
# Epoch 161, loss 0.2354, val_loss 0.2251
# Epoch 162, loss 0.2252, val_loss 0.1827
# Epoch 163, loss 0.2111, val_loss 0.1835
# Epoch 164, loss 0.2231, val_loss 0.1813
# Epoch 165, loss 0.2137, val_loss 0.1754
# Epoch 166, loss 0.2304, val_loss 0.1862
# Epoch 167, loss 0.2390, val_loss 0.1967
# Epoch 168, loss 0.2165, val_loss 0.1745
# Epoch 169, loss 0.2114, val_loss 0.1775
# Epoch 170, loss 0.2192, val_loss 0.1958
# Epoch 171, loss 0.2236, val_loss 0.1779
# Epoch 172, loss 0.2168, val_loss 0.2433
# Epoch 173, loss 0.2587, val_loss 0.1953
# Epoch 174, loss 0.2464, val_loss 0.1945
# Epoch 175, loss 0.2336, val_loss 0.1859
# Epoch 176, loss 0.2261, val_loss 0.1747
# Epoch 177, loss 0.2157, val_loss 0.1843
# Epoch 178, loss 0.2254, val_loss 0.2146
# Epoch 179, loss 0.2270, val_loss 0.1901
# Epoch 180, loss 0.2330, val_loss 0.1779
# Epoch 181, loss 0.2104, val_loss 0.1768
# Epoch 182, loss 0.2155, val_loss 0.1709
# Epoch 183, loss 0.2188, val_loss 0.1697
# Epoch 184, loss 0.2235, val_loss 0.1808
# Epoch 185, loss 0.2133, val_loss 0.1696
# Epoch 186, loss 0.2120, val_loss 0.2090
# Epoch 187, loss 0.2183, val_loss 0.1845
# Epoch 188, loss 0.2220, val_loss 0.1933
# Epoch 189, loss 0.2126, val_loss 0.1681
# Epoch 190, loss 0.2248, val_loss 0.1740
# Epoch 191, loss 0.2048, val_loss 0.1655
# Epoch 192, loss 0.2155, val_loss 0.1707
# Epoch 193, loss 0.2193, val_loss 0.1883
# Epoch 194, loss 0.2147, val_loss 0.1938
# Epoch 195, loss 0.2184, val_loss 0.1935
# Epoch 196, loss 0.2341, val_loss 0.1644
# Epoch 197, loss 0.2087, val_loss 0.1694
# Epoch 198, loss 0.2118, val_loss 0.2007
# Epoch 199, loss 0.2184, val_loss 0.1775
# Epoch 200, loss 0.2231, val_loss 0.1967

# %%
import numpy as np

plt.rcParams["figure.figsize"]=10,10

plt.plot( range(1, n_epoch+1), np.array(epoch_losses), label='Training Loss' )
plt.plot( range(1, n_epoch+1), np.array(epoch_val_losses), label='Validation Loss' )
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.eval()
# Convert a list of tuples to two lists
test_X, test_Y = map(list, zip(*testset))
test_bg = dgl.batch(test_X)
test_Y = torch.tensor(test_Y).float().view(-1, 1)
probs_Y = torch.softmax(model(test_bg), 1)
sampled_Y = torch.multinomial(probs_Y.cpu() , 1)
argmax_Y = torch.max(probs_Y.cpu(), 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_Y == sampled_Y.float()).sum().item() / len(test_Y) * 100))
# print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
#     (test_Y == argmax_Y.float()).sum().item() / len(test_Y) * 100))
# Out:
# Accuracy of sampled predictions on the test set: 85.0000%
